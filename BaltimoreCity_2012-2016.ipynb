# %%
### 2012-2016 Census Data (ACS 5-year)for Selected Variables - Baltimore City Totals

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states
import censusdata 
import censusgeocode as cg
import cenpy
import gmaps
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Census & gmaps API Keys
# the latest year available is the default year and so you do not need to specify the year

from config import (api_key, gkey)
c = Census(api_key)

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\BDC\\Commercial_corridors\\Commercial_Corridors_Demographics'

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 100)

# %%
# Save the acreage/ square mile data (csv file) in variable

data_SQMI = "BaltCity_SQ_mile.csv"

# %%
# Create dataframe by reading the variable data from the code block above
Balt_SQMI_df = pd.read_csv(data_SQMI)
Balt_SQMI_df
# Out:
#                        Name  Area_Acres  Area_mi2
# 0  Baltimore city, Maryland       59060     92.28

# %%
Balt_SQMI_df.dtypes
# Out:
# Name           object
# Area_Acres      int64
# Area_mi2      float64
# dtype: object

# %%
# American Community Survey 5-Year Data DETAILED Tables 
# The data are population COUNTS


# Set this to false if you're trying to do this without an internet connection
# and data which would have been fetched from an API query will be read from cached files instead
INTERNET_IS_WORKING = True

if INTERNET_IS_WORKING:
    con = cenpy.remote.APIConnection('ACSDT5Y2016')
    variables = con.variables
else:
    variables = pd.read_csv('data/ACSDT5Y2016_variables.csv',index_col='Unnamed: 0')


variables.head()
# Out:
#                                                                                                       label  \
# for                                                                            Census API FIPS 'for' clause
# in                                                                              Census API FIPS 'in' clause
# ucgid                                                            Uniform Census Geography Identifier clause
# B99104_007E                               Estimate!!Total!!Not living with own grandchildren under 18 years
# B24022_060E  Estimate!!Total!!Female!!Service occupations!!Food preparation and serving related occupations
#
#                                                                                                          concept  \
# for                                                                           Census API Geography Specification
# in                                                                            Census API Geography Specification
# ucgid                                                                         Census API Geography Specification
# B99104_007E  ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR TH...
# B24022_060E  SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)...
#
#             predicateType   group limit predicateOnly hasGeoCollectionSupport  \
# for              fips-for     N/A     0          True                     NaN
# in                fips-in     N/A     0          True                     NaN
# ucgid               ucgid     N/A     0          True                    True
# B99104_007E           int  B99104     0           NaN                     NaN
# B24022_060E           int  B24022     0           NaN                     NaN
#
#                                         attributes required values
# for                                            NaN      NaN    NaN
# in                                             NaN      NaN    NaN
# ucgid                                          NaN      NaN    NaN
# B99104_007E                           B99104_007EA      NaN    NaN
# B24022_060E  B24022_060EA,B24022_060M,B24022_060MA      NaN    NaN

# %%
# Run Census Search to retrieve data on Baltimore City, MD 
# ***See https://api.census.gov/data/2019/acs/acs5/groups.html  for list of variables and groups for the ACS 5-year estimates***
# ex. "B23025_005E" is "unemployment count"
# The state FIPS code for MD is 24 and the FIPS code for Balt City is 510
census_data = c.acs5.state_county(("NAME","B11002_001E", 
                          "B19001_001E","B19013_001E", "B01003_001E", "B01002_001E",
                          "B02001_002E",
                          "B02001_003E",
                          "B02001_005E",              
                          "B02001_008E",
                          "B03001_003E",
                          "B05002_013E",
                          "B08301_001E",               
                          "B08301_010E",
                          "B15003_001E",
                          "B15003_016E",               
                          "B15003_017E",
                          "B15003_021E",               
                          "B15003_022E", 
                          "B17021_001E",
                          "B17021_002E",        
                          "B19301_001E",               
                          "B23025_001E",
                          "B23025_002E",
                          "B23025_004E",
                          "B23025_005E",              
                          "B23025_007E",
                          "B25044_003E",
                          "B25044_010E",
                          "B25008_002E",
                          "B25003_001E",               
                          "B25003_002E",                                    
                          "B25003_003E",
                          "B28003_005E",
                          "B28003_006E",
                          "C17002_001E",
                          "C24030_001E",        
                          "C24030_006E",                
                          "C24030_007E", 
                          "C24030_009E",                
                          "C24030_010E",                
                          "C24030_014E",                
                          "C24030_017E",                
                          "C24030_021E",                
                          "C24030_024E",
                          "C24030_028E",              
                          "C24030_033E",                
                          "C24030_034E",                
                          "C24030_036E",                
                          "C24030_037E",                
                          "C24030_041E",  
                          "C24030_044E",               
                          "C24030_048E",                
                          "C24030_051E",
                          "C24030_055E"),
                          state_fips = "24",
                          county_fips = "510",
                          )
census_pd = pd.DataFrame(census_data)
census_pd.head()
# Out:
#                        NAME  B11002_001E  B19001_001E  B19013_001E  \
# 0  Baltimore city, Maryland     590812.0     238436.0      48840.0
#
#    B01003_001E  B01002_001E  B02001_002E  B02001_003E  B02001_005E  \
# 0     614700.0         35.1     187152.0     383918.0      15898.0
#
#    B02001_008E  ...  C24030_036E          GEO_ID  state  county  C24030_037E  \
# 0      15325.0  ...      13288.0  0500000US24510     24     510       4605.0
#
#    C24030_041E  C24030_044E  C24030_048E  C24030_051E  C24030_055E
# 0       8087.0      15521.0      63444.0      12201.0      13515.0
#
# [1 rows x 58 columns]

# %%
# Pull values from the ACS 5 yr. census codes/ variables listed and save them in the variable "age_data"

age_data = c.acs5.state_county(("NAME", "B01001_003E",                                    
                          "B01001_004E",
                          "B01001_005E",
                          "B01001_006E",
                          "B01001_007E",
                          "B01001_008E",
                          "B01001_009E",
                          "B01001_010E",
                          "B01001_011E",
                          "B01001_012E",
                          "B01001_013E",
                          "B01001_014E",
                          "B01001_015E",
                          "B01001_016E",            
                          "B01001_017E",
                          "B01001_018E",
                          "B01001_019E",
                          "B01001_020E",
                          "B01001_021E",
                          "B01001_022E",
                          "B01001_023E",
                          "B01001_024E",
                          "B01001_025E",
                          "B01001_027E",
                          "B01001_028E",
                          "B01001_029E",
                          "B01001_030E",
                          "B01001_031E",
                          "B01001_032E",
                          "B01001_033E",
                          "B01001_034E",
                          "B01001_035E",
                          "B01001_036E",
                          "B01001_037E",
                          "B01001_038E",
                          "B01001_039E",            
                          "B01001_040E",
                          "B01001_041E",
                          "B01001_042E",
                          "B01001_043E",
                          "B01001_044E",
                          "B01001_045E",
                          "B01001_046E",
                          "B01001_047E",
                          "B01001_048E",
                          "B01001_049E"),          
                          state_fips = "24",
                          county_fips = "510",
                         )
age_pd = pd.DataFrame(age_data)
age_pd.head()
# Out:
#                        NAME  B01001_003E  B01001_004E  B01001_005E  \
# 0  Baltimore city, Maryland      20357.0      18021.0      16926.0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  \
# 0       9570.0       8068.0       4682.0       4790.0      12019.0
#
#    B01001_011E  ...  B01001_042E  B01001_043E  B01001_044E  B01001_045E  \
# 0      29510.0  ...       8708.0      12208.0       7092.0       8953.0
#
#    B01001_046E  B01001_047E  B01001_048E  B01001_049E  state  county
# 0      11030.0       8274.0       6375.0       6730.0     24     510
#
# [1 rows x 49 columns]

# %%
# Sum columns of age groups that are under 18 years old for male and female and add new column "Pop. <18 years"
columns_under18 = ["B01001_003E",                                    
                   "B01001_004E",
                   "B01001_005E",
                   "B01001_006E",
                   "B01001_027E",
                   "B01001_028E",
                   "B01001_029E",
                   "B01001_030E"]
age_pd['Pop. <18 years']= age_pd[columns_under18].sum(axis=1)
age_pd.head()
# Out:
#                        NAME  B01001_003E  B01001_004E  B01001_005E  \
# 0  Baltimore city, Maryland      20357.0      18021.0      16926.0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  \
# 0       9570.0       8068.0       4682.0       4790.0      12019.0
#
#    B01001_011E  ...  B01001_043E  B01001_044E  B01001_045E  B01001_046E  \
# 0      29510.0  ...      12208.0       7092.0       8953.0      11030.0
#
#    B01001_047E  B01001_048E  B01001_049E  state  county  Pop. <18 years
# 0       8274.0       6375.0       6730.0     24     510        128219.0
#
# [1 rows x 50 columns]

# %%
# Sum columns of age groups that are 18-64 years old (working age) for male and female and add new column "Pop. working age"
columns_working_age = [                                    
                   "B01001_007E",
                   "B01001_008E",
                   "B01001_009E",
                   "B01001_010E",
                   "B01001_011E",
                   "B01001_012E",   
                   "B01001_013E",
                   "B01001_014E",    
                   "B01001_015E",    
                   "B01001_016E",   
                   "B01001_017E", 
                   "B01001_018E",    
                   "B01001_019E",    
                   "B01001_031E",
                   "B01001_032E",
                   "B01001_033E",
                   "B01001_034E",
                   "B01001_035E",   
                   "B01001_036E",
                   "B01001_037E",    
                   "B01001_038E",    
                   "B01001_039E",   
                   "B01001_040E", 
                   "B01001_041E",    
                   "B01001_042E",    
                   "B01001_043E"]    
                           
age_pd['Pop. working age']= age_pd[columns_working_age].sum(axis=1)
age_pd.head()
# Out:
#                        NAME  B01001_003E  B01001_004E  B01001_005E  \
# 0  Baltimore city, Maryland      20357.0      18021.0      16926.0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  \
# 0       9570.0       8068.0       4682.0       4790.0      12019.0
#
#    B01001_011E  ...  B01001_044E  B01001_045E  B01001_046E  B01001_047E  \
# 0      29510.0  ...       7092.0       8953.0      11030.0       8274.0
#
#    B01001_048E  B01001_049E  state  county  Pop. <18 years  Pop. working age
# 0       6375.0       6730.0     24     510        128219.0          405635.0
#
# [1 rows x 51 columns]

# %%
# Sum columns of age groups that are 65+ years old for male and female and add new column "Pop. 65+ years"
columns_senior = ["B01001_020E",
                  "B01001_021E",
                  "B01001_022E",
                  "B01001_023E",                                    
                  "B01001_024E",
                  "B01001_025E",
                  "B01001_044E",
                  "B01001_045E",
                  "B01001_046E",
                  "B01001_047E",                                    
                  "B01001_048E",
                  "B01001_049E"]               
                          
age_pd['Pop. 65+ years']= age_pd[columns_senior].sum(axis=1)
age_pd.head()
# Out:
#                        NAME  B01001_003E  B01001_004E  B01001_005E  \
# 0  Baltimore city, Maryland      20357.0      18021.0      16926.0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  \
# 0       9570.0       8068.0       4682.0       4790.0      12019.0
#
#    B01001_011E  ...  B01001_045E  B01001_046E  B01001_047E  B01001_048E  \
# 0      29510.0  ...       8953.0      11030.0       8274.0       6375.0
#
#    B01001_049E  state  county  Pop. <18 years  Pop. working age  \
# 0       6730.0     24     510        128219.0          405635.0
#
#    Pop. 65+ years
# 0         80846.0
#
# [1 rows x 52 columns]

# %%
# Rename "NAME" column so we can join/ merge it with other dfs later on the "Name" column
age_pd = age_pd.rename(columns={"NAME": "Name"
                               })
age_pd
# Out:
#                        Name  B01001_003E  B01001_004E  B01001_005E  \
# 0  Baltimore city, Maryland      20357.0      18021.0      16926.0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  \
# 0       9570.0       8068.0       4682.0       4790.0      12019.0
#
#    B01001_011E  ...  B01001_045E  B01001_046E  B01001_047E  B01001_048E  \
# 0      29510.0  ...       8953.0      11030.0       8274.0       6375.0
#
#    B01001_049E  state  county  Pop. <18 years  Pop. working age  \
# 0       6730.0     24     510        128219.0          405635.0
#
#    Pop. 65+ years
# 0         80846.0
#
# [1 rows x 52 columns]

# %%
age_temp = age_pd[[ "Name","state", "county", "Pop. <18 years", "Pop. working age", "Pop. 65+ years"]]
age_temp.head()
# Out:
#                        Name state county  Pop. <18 years  Pop. working age  \
# 0  Baltimore city, Maryland    24    510        128219.0          405635.0
#
#    Pop. 65+ years
# 0         80846.0

# %%
age_temp.dtypes
# Out:
# Name                 object
# state                object
# county               object
# Pop. <18 years      float64
# Pop. working age    float64
# Pop. 65+ years      float64
# dtype: object

# %%
age_final = age_temp.copy()

# %%
# Did not add in daytime population - will use ESRI business analyst for this 
# See https://www.census.gov/topics/employment/commuting/guidance/calculations.html
# "commuter-adjusted daytime population estimates" =    
#         total resident population + total workers working in area - total workers living in area

# For "Workers in Workplace Geography," see https://www.census.gov/topics/employment/commuting/guidance/calculations.html
# "Total workers working in area:
# B08604 Total Workers for Workplace Geography
# B08604 is only available for data years 2011 and after. 
# The tables for workplace geography are only available for the following geographic summary levels: States; 
# Counties; Places; County Subdivisions in selected states (not MD); Combined Statistical Areas; Metropolitan 
# and Micropolitan Statistical Areas, and their associated Metropolitan Divisions and Principal Cities; 

census_data_workers = c.acs5.state_county(("NAME", 
                          "B08604_001E"),               
                          state_fips = "24",
                          county_fips = "510") 

# convert to dataframe
workers_df = pd.DataFrame(census_data_workers)
workers_df
# Out:
#                        NAME  B08604_001E state county
# 0  Baltimore city, Maryland     382638.0    24    510

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with text so it's understandable
census_pd = census_pd.rename(columns={"B19001_001E": "Total households",
                                      "B01003_001E": "Population",
                                      "tract": "Census Tract",  
                                      "B08301_001E": "Workers_16_yrs_and_over",  
                                      "B08301_010E": "Commute_to_work_public_transportation",       
                                      "B01002_001E": "Median age",
                                      "B02001_002E": "Pop. white",
                                      "B02001_003E": "Pop. Black",
                                      "B02001_005E": "Pop. Asian",        
                                      "B02001_008E": "Pop. two or more races",
                                      "B03001_003E": "Pop. Hispanic origin",
                                      "B05002_013E": "# Foreign-born",
                                      "B11002_001E": "Household population",
                                      "B15003_001E": "Population_25_yrs_and_over",
                                      "B15003_016E": "# persons 12th grade, no diploma",
                                      "B15003_017E": "# persons graduated high school",
                                      "B15003_021E": "# persons Associate's degree",
                                      "B15003_022E": "# persons Bachelor's degree",
                                      "B19013_001E": "Median household income",
                                      "B19301_001E": "Per capita income", 
                                      "B17021_001E": "Persons_poverty_status_determined",
                                      "B17021_002E": "Income_past_12mos_below_pov_level",
                                      "B23025_001E": "Pop_16_yrs_and_over",
                                      "B23025_002E": "Pop_in_labor_force",
                                      "B23025_004E": "Employed_civilians",
                                      "B23025_005E": "Unemployed_civilians",
                                      "B23025_007E": "Pop_NOT_in_labor_force",
                                      "B25008_002E": "Total pop. in occupied housing units by tenure",
                                      "B25003_001E": "Total occupied units",
                                      "B25003_002E": "Total owner-occupied units",
                                      "B25003_003E": "Total renter-occupied units",
                                      "B25044_003E": "No_vehicle_available_owneroccupied_unit",
                                      "B25044_010E": "No_vehicle_available_renteroccupied_unit",
                                      "B28003_005E": "# households with computer, no internet subscription",
                                      "B28003_006E": "# households no computer",
                                      "C24030_001E": "Civilian_employed_pop_16yrs_and_over",
                                      "C24030_006E": "ConstructionM", 
                                      "C24030_007E": "ManufacturingM", 
                                      "C24030_009E": "Retail_TradeM",
                                      "C24030_010E": "Transportation_warehousing_utilitiesM",
                                      "C24030_014E": "Finance_insurance_realestateM",               
                                      "C24030_017E": "Professional_scientific_mgmt_administrativeM",              
                                      "C24030_021E": "Educational_healthcare_socialM",                
                                      "C24030_024E": "Accommodations_foodservices_arts_entertainmentM",
                                      "C24030_028E": "Public_administrationM",
                                      "C24030_033E": "ConstructionF",                
                                      "C24030_034E": "ManufacturingF",
                                      "C24030_036E": "Retail_TradeF",                
                                      "C24030_037E": "Transportation_warehousing_utilitiesF",                
                                      "C24030_041E": "Finance_insurance_realestateF",  
                                      "C24030_044E": "Professional_scientific_mgmt_administrativeF",               
                                      "C24030_048E": "Educational_healthcare_socialF",
                                      "C24030_051E": "Accommodations_foodservices_arts_entertainmentF",
                                      "C24030_055E": "Public_administrationF",
                                      "NAME": "Name", "state": "State", "GEOID": "GEOID"
                                     })
census_pd
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Retail_TradeF          GEO_ID  \
# 0     15898.0                 15325.0  ...        13288.0  0500000US24510
#
#    State  county  Transportation_warehousing_utilitiesF  \
# 0     24     510                                 4605.0
#
#    Finance_insurance_realestateF  \
# 0                         8087.0
#
#    Professional_scientific_mgmt_administrativeF  \
# 0                                       15521.0
#
#    Educational_healthcare_socialF  \
# 0                         63444.0
#
#    Accommodations_foodservices_arts_entertainmentF  Public_administrationF
# 0                                          12201.0                 13515.0
#
# [1 rows x 58 columns]

# %%
census_pd.columns
# Out:
# Index(['Name', 'Household population', 'Total households',
#        'Median household income', 'Population', 'Median age', 'Pop. white',
#        'Pop. Black', 'Pop. Asian', 'Pop. two or more races',
#        'Pop. Hispanic origin', '# Foreign-born', 'Workers_16_yrs_and_over',
#        'Commute_to_work_public_transportation', 'Population_25_yrs_and_over',
#        '# persons 12th grade, no diploma', '# persons graduated high school',
#        '# persons Associate's degree', '# persons Bachelor's degree',
#        'Persons_poverty_status_determined',
#        'Income_past_12mos_below_pov_level', 'Per capita income',
#        'Pop_16_yrs_and_over', 'Pop_in_labor_force', 'Employed_civilians',
#        'Unemployed_civilians', 'Pop_NOT_in_labor_force',
#        'No_vehicle_available_owneroccupied_unit',
#        'No_vehicle_available_renteroccupied_unit',
#        'Total pop. in occupied housing units by tenure',
#        'Total occupied units', 'Total owner-occupied units',
#        'Total renter-occupied units',
#        '# households with computer, no internet subscription',
#        '# households no computer', 'C17002_001E',
#        'Civilian_employed_pop_16yrs_and_over', 'ConstructionM',
#        'ManufacturingM', 'Retail_TradeM',
#        'Transportation_warehousing_utilitiesM',
#        'Finance_insurance_realestateM',
#        'Professional_scientific_mgmt_administrativeM',
#        'Educational_healthcare_socialM',
#        'Accommodations_foodservices_arts_entertainmentM',
#        'Public_administrationM', 'ConstructionF', 'ManufacturingF',
#        'Retail_TradeF', 'GEO_ID', 'State', 'county',
#        'Transportation_warehousing_utilitiesF',
#        'Finance_insurance_realestateF',
#        'Professional_scientific_mgmt_administrativeF',
#        'Educational_healthcare_socialF',
#        'Accommodations_foodservices_arts_entertainmentF',
#        'Public_administrationF'],
#       dtype='object')

# %%
census_pd["Construction count"] = census_pd["ConstructionM"].astype(
        int) + census_pd["ConstructionF"].astype(
        int) 
census_pd.head()
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...          GEO_ID  State  county  \
# 0     15898.0                 15325.0  ...  0500000US24510     24     510
#
#    Transportation_warehousing_utilitiesF  Finance_insurance_realestateF  \
# 0                                 4605.0                         8087.0
#
#    Professional_scientific_mgmt_administrativeF  \
# 0                                       15521.0
#
#    Educational_healthcare_socialF  \
# 0                         63444.0
#
#    Accommodations_foodservices_arts_entertainmentF  Public_administrationF  \
# 0                                          12201.0                 13515.0
#
#    Construction count
# 0               12537
#
# [1 rows x 59 columns]

# %%
census_pd["Manufacturing count"] = census_pd["ManufacturingM"].astype(
        int) + census_pd["ManufacturingF"].astype(
        int)

# %%
census_pd["Retail_Trade count"] = census_pd["Retail_TradeM"].astype(
        int) + census_pd["Retail_TradeF"].astype(
        int)

# %%
census_pd["Transportation_warehousing_utilities count"] = census_pd["Transportation_warehousing_utilitiesM"].astype(
        int) + census_pd["Transportation_warehousing_utilitiesF"].astype(
        int)

# %%
census_pd["Finance_insurance_realestate count"] = census_pd["Finance_insurance_realestateM"].astype(
        int) + census_pd["Finance_insurance_realestateF"].astype(
        int)

# %%
census_pd["Professional_scientific_mgmt_administrative count"] = census_pd["Professional_scientific_mgmt_administrativeM"].astype(
        int) + census_pd["Professional_scientific_mgmt_administrativeF"].astype(
        int)

# %%
census_pd["Educational_healthcare_social count"] = census_pd["Educational_healthcare_socialM"].astype(
        int) + census_pd["Educational_healthcare_socialF"].astype(
        int)

# %%
census_pd["Accommodations_foodservices_arts_entertainment count"] = census_pd["Accommodations_foodservices_arts_entertainmentM"].astype(
        int) + census_pd["Accommodations_foodservices_arts_entertainmentF"].astype(
        int)

# %%
census_pd["Public_administration count"] = census_pd["Public_administrationM"].astype(
        int) + census_pd["Public_administrationF"].astype(
        int)

# %%
# merge the census_pd dataframe with the age_final dataframe on the common column "NAME"
census_Balt = pd.merge(
    census_pd, age_final, on="Name"
                        )
census_Balt
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Finance_insurance_realestate count  \
# 0                               15700
#
#    Professional_scientific_mgmt_administrative count  \
# 0                                              34809
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  state  county_y  Pop. <18 years  \
# 0                        22659     24       510        128219.0
#
#    Pop. working age  Pop. 65+ years
# 0          405635.0         80846.0
#
# [1 rows x 72 columns]

# %%
# merge the census_Balt dataframe with the Balt_SQMI_dfdataframe on the common column "Name"
census_Balt1 = pd.merge(
    census_Balt, Balt_SQMI_df, on="Name"
                        )
census_Balt1
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  state  county_y  Pop. <18 years  \
# 0                        22659     24       510        128219.0
#
#    Pop. working age  Pop. 65+ years  Area_Acres  Area_mi2
# 0          405635.0         80846.0       59060     92.28
#
# [1 rows x 74 columns]

# %%
census_Balt1.columns
# Out:
# Index(['Name', 'Household population', 'Total households',
#        'Median household income', 'Population', 'Median age', 'Pop. white',
#        'Pop. Black', 'Pop. Asian', 'Pop. two or more races',
#        'Pop. Hispanic origin', '# Foreign-born', 'Workers_16_yrs_and_over',
#        'Commute_to_work_public_transportation', 'Population_25_yrs_and_over',
#        '# persons 12th grade, no diploma', '# persons graduated high school',
#        '# persons Associate's degree', '# persons Bachelor's degree',
#        'Persons_poverty_status_determined',
#        'Income_past_12mos_below_pov_level', 'Per capita income',
#        'Pop_16_yrs_and_over', 'Pop_in_labor_force', 'Employed_civilians',
#        'Unemployed_civilians', 'Pop_NOT_in_labor_force',
#        'No_vehicle_available_owneroccupied_unit',
#        'No_vehicle_available_renteroccupied_unit',
#        'Total pop. in occupied housing units by tenure',
#        'Total occupied units', 'Total owner-occupied units',
#        'Total renter-occupied units',
#        '# households with computer, no internet subscription',
#        '# households no computer', 'C17002_001E',
#        'Civilian_employed_pop_16yrs_and_over', 'ConstructionM',
#        'ManufacturingM', 'Retail_TradeM',
#        'Transportation_warehousing_utilitiesM',
#        'Finance_insurance_realestateM',
#        'Professional_scientific_mgmt_administrativeM',
#        'Educational_healthcare_socialM',
#        'Accommodations_foodservices_arts_entertainmentM',
#        'Public_administrationM', 'ConstructionF', 'ManufacturingF',
#        'Retail_TradeF', 'GEO_ID', 'State', 'county_x',
#        'Transportation_warehousing_utilitiesF',
#        'Finance_insurance_realestateF',
#        'Professional_scientific_mgmt_administrativeF',
#        'Educational_healthcare_socialF',
#        'Accommodations_foodservices_arts_entertainmentF',
#        'Public_administrationF', 'Construction count', 'Manufacturing count',
#        'Retail_Trade count', 'Transportation_warehousing_utilities count',
#        'Finance_insurance_realestate count',
#        'Professional_scientific_mgmt_administrative count',
#        'Educational_healthcare_social count',
#        'Accommodations_foodservices_arts_entertainment count',
#        'Public_administration count', 'state', 'county_y', 'Pop. <18 years',
#        'Pop. working age', 'Pop. 65+ years', 'Area_Acres', 'Area_mi2'],
#       dtype='object')

# %%
# Drop extraneous columns
census_Balt1 = census_Balt1.drop(["State", "county_x", "state", "county_y"], axis=1)

# %%
census_Balt_final = census_Balt1.copy()

# %%
census_Balt_final["Total occupied units"] = census_Balt_final.loc[:, ["Total owner-occupied units", "Total renter-occupied units"]].sum(axis=1)
census_Balt_final
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Finance_insurance_realestate count  \
# 0                               15700
#
#    Professional_scientific_mgmt_administrative count  \
# 0                                              34809
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  Pop. <18 years  Pop. working age  \
# 0                        22659        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2
# 0         80846.0       59060     92.28
#
# [1 rows x 70 columns]

# %%
Balt_percentages = census_Balt_final.copy()
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Finance_insurance_realestate count  \
# 0                               15700
#
#    Professional_scientific_mgmt_administrative count  \
# 0                                              34809
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  Pop. <18 years  Pop. working age  \
# 0                        22659        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2
# 0         80846.0       59060     92.28
#
# [1 rows x 70 columns]

# %%
# Calculate population density  see: https://www.census.gov/quickfacts/fact/note/US/LND110210
# Density is expressed as "population per square mile(kilometer)"
# Divide total population (or # of housing units)/ by land area of the entity measured in square miles
Balt_percentages['Pop. density per sq mile'] = Balt_percentages['Population'].astype(
                                    float) / Balt_percentages['Area_mi2'].astype(
                                    float)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Professional_scientific_mgmt_administrative count  \
# 0                                              34809
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  Pop. <18 years  Pop. working age  \
# 0                        22659        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2  Pop. density per sq mile
# 0         80846.0       59060     92.28               6661.248375
#
# [1 rows x 71 columns]

# %%
# Round to one decimal point; using "float" instead of "int" because want to use decimal points
Balt_percentages["Pop. density per sq mile"] = Balt_percentages["Pop. density per sq mile"].astype(float).round(1)

# %%
Balt_percentages["Home ownership rate"] = 100 * \
    Balt_percentages["Total owner-occupied units"].astype(
        int) / Balt_percentages["Total occupied units"].astype(
        int) 

Balt_percentages.head()
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Educational_healthcare_social count  \
# 0                                88531
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  Pop. <18 years  Pop. working age  \
# 0                        22659        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2  Pop. density per sq mile  \
# 0         80846.0       59060     92.28                    6661.2
#
#    Home ownership rate
# 0            47.348974
#
# [1 rows x 72 columns]

# %%
# Round the home ownership rate to one decimal point; using "float" instead of "int" because want to use decimal points
Balt_percentages["Home ownership rate"] = Balt_percentages["Home ownership rate"].astype(float).round(1)

# %%
# Add a new column for average household size (Household population / Total households); see https://www.census.gov/quickfacts/fact/note/US/HSD410221#:~:text=Persons%20per%20household%2C%20or%20average,by%20the%20number%20of%20households.
Balt_percentages["Average hh size"] = Balt_percentages["Household population"].astype(
        int) / Balt_percentages["Total households"].astype(int)

Balt_percentages["Average hh size"] = Balt_percentages["Average hh size"].astype(float).round(2)

Balt_percentages.head()
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  \
# 0     15898.0                 15325.0  ...
#
#    Accommodations_foodservices_arts_entertainment count  \
# 0                                                 25274
#
#    Public_administration count  Pop. <18 years  Pop. working age  \
# 0                        22659        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2  Pop. density per sq mile  \
# 0         80846.0       59060     92.28                    6661.2
#
#    Home ownership rate  Average hh size
# 0                 47.3             2.48
#
# [1 rows x 73 columns]

# %%
# Add a new column for # of occupied units with no vehicle available (sum column values of owner-occupied units with no vehicles available
# and renter-occupied units with no vehicles available)

Balt_percentages["Number units with no vehicle available"] = Balt_percentages.apply(lambda row: row.No_vehicle_available_owneroccupied_unit + row.No_vehicle_available_renteroccupied_unit, axis=1) 
Balt_percentages.head()
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Public_administration count  \
# 0     15898.0                 15325.0  ...                        22659
#
#    Pop. <18 years  Pop. working age  Pop. 65+ years  Area_Acres  Area_mi2  \
# 0        128219.0          405635.0         80846.0       59060     92.28
#
#    Pop. density per sq mile  Home ownership rate  Average hh size  \
# 0                    6661.2                 47.3             2.48
#
#    Number units with no vehicle available
# 0                                 68829.0
#
# [1 rows x 74 columns]

# %%
# Add a new column for % of occupied units with no vehicle available 
# (owner-occupied units with no vehicle available + renter-occupied units with no vehicle available / Total occupied units)
Balt_percentages["Percent units with no vehicle available"] = 100 * \
    Balt_percentages["Number units with no vehicle available"].astype(
        int) / Balt_percentages["Total occupied units"].astype(
        int) 

Balt_percentages["Percent units with no vehicle available"] = Balt_percentages["Percent units with no vehicle available"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Pop. <18 years  Pop. working age  \
# 0     15898.0                 15325.0  ...        128219.0          405635.0
#
#    Pop. 65+ years  Area_Acres  Area_mi2  Pop. density per sq mile  \
# 0         80846.0       59060     92.28                    6661.2
#
#    Home ownership rate  Average hh size  \
# 0                 47.3             2.48
#
#    Number units with no vehicle available  \
# 0                                 68829.0
#
#    Percent units with no vehicle available
# 0                                     28.9
#
# [1 rows x 75 columns]

# %%
Balt_percentages["Percent commute to work public transportation"] = 100 * \
    Balt_percentages["Commute_to_work_public_transportation"].astype(
        int) / Balt_percentages["Workers_16_yrs_and_over"].astype(
        int) 

Balt_percentages["Percent commute to work public transportation"] = Balt_percentages["Percent commute to work public transportation"].astype(float).round(1)

# %%
Balt_percentages["Percent Black"] = 100 * \
    Balt_percentages["Pop. Black"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 

Balt_percentages["Percent Black"] = Balt_percentages["Percent Black"].astype(float).round(1)

# %%
Balt_percentages["Percent white"] = 100 * \
    Balt_percentages["Pop. white"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent white"] = Balt_percentages["Percent white"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Area_Acres  Area_mi2  \
# 0     15898.0                 15325.0  ...       59060     92.28
#
#    Pop. density per sq mile  Home ownership rate  Average hh size  \
# 0                    6661.2                 47.3             2.48
#
#    Number units with no vehicle available  \
# 0                                 68829.0
#
#    Percent units with no vehicle available  \
# 0                                     28.9
#
#    Percent commute to work public transportation  Percent Black  Percent white
# 0                                           18.0           62.5           30.4
#
# [1 rows x 78 columns]

# %%
Balt_percentages["Percent Asian"] = 100 * \
    Balt_percentages["Pop. Asian"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent Asian"] = Balt_percentages["Percent Asian"].astype(float).round(1)

# %%
Balt_percentages["Percent Hispanic origin"] = 100 * \
    Balt_percentages["Pop. Hispanic origin"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent Hispanic origin"] = Balt_percentages["Percent Hispanic origin"].astype(float).round(1)

# %%
Balt_percentages["Percent two or more races"] = 100 * \
    Balt_percentages["Pop. two or more races"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent two or more races"] = Balt_percentages["Percent two or more races"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Home ownership rate  \
# 0     15898.0                 15325.0  ...                 47.3
#
#    Average hh size  Number units with no vehicle available  \
# 0             2.48                                 68829.0
#
#    Percent units with no vehicle available  \
# 0                                     28.9
#
#    Percent commute to work public transportation  Percent Black  \
# 0                                           18.0           62.5
#
#    Percent white  Percent Asian  Percent Hispanic origin  \
# 0           30.4            2.6                      5.1
#
#    Percent two or more races
# 0                        2.5
#
# [1 rows x 81 columns]

# %%
Balt_percentages["Percent 12th grade, no diploma"] = 100 * \
    Balt_percentages["# persons 12th grade, no diploma"].astype(
        int) / Balt_percentages["Population_25_yrs_and_over"].astype(
        int) 
Balt_percentages["Percent 12th grade, no diploma"] = Balt_percentages["Percent 12th grade, no diploma"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Average hh size  \
# 0     15898.0                 15325.0  ...             2.48
#
#    Number units with no vehicle available  \
# 0                                 68829.0
#
#    Percent units with no vehicle available  \
# 0                                     28.9
#
#    Percent commute to work public transportation  Percent Black  \
# 0                                           18.0           62.5
#
#    Percent white  Percent Asian  Percent Hispanic origin  \
# 0           30.4            2.6                      5.1
#
#    Percent two or more races  Percent 12th grade, no diploma
# 0                        2.5                             2.1
#
# [1 rows x 82 columns]

# %%
Balt_percentages["Percent graduated high school"] = 100 * \
    Balt_percentages["# persons graduated high school"].astype(
        int) / Balt_percentages["Population_25_yrs_and_over"].astype(
        int) 
Balt_percentages["Percent graduated high school"] = Balt_percentages["Percent graduated high school"].astype(float).round(1)

# %%
Balt_percentages["Percent earned Associate's degree"] = 100 * \
    Balt_percentages["# persons Associate's degree"].astype(
        int) / Balt_percentages["Population_25_yrs_and_over"].astype(
        int) 
Balt_percentages["Percent earned Associate's degree"] = Balt_percentages["Percent earned Associate's degree"].astype(float).round(1)

# %%
Balt_percentages["Percent earned Bachelor's degree"] = 100 * \
    Balt_percentages["# persons Bachelor's degree"].astype(
        int) / Balt_percentages["Population_25_yrs_and_over"].astype(
        int) 
Balt_percentages["Percent earned Bachelor's degree"] = Balt_percentages["Percent earned Bachelor's degree"].astype(float).round(1)

# %%
Balt_percentages["Percent computer, no internet subscription"] = 100 * \
    Balt_percentages["# households with computer, no internet subscription"].astype(
        int) / Balt_percentages["Total households"].astype(
        int) 
Balt_percentages["Percent computer, no internet subscription"] = Balt_percentages["Percent computer, no internet subscription"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent Black  Percent white  \
# 0     15898.0                 15325.0  ...           62.5           30.4
#
#    Percent Asian  Percent Hispanic origin  Percent two or more races  \
# 0            2.6                      5.1                        2.5
#
#    Percent 12th grade, no diploma  Percent graduated high school  \
# 0                             2.1                           25.0
#
#    Percent earned Associate's degree  Percent earned Bachelor's degree  \
# 0                                4.8                              16.3
#
#    Percent computer, no internet subscription
# 0                                        12.2
#
# [1 rows x 86 columns]

# %%
Balt_percentages["Percent no computer"] = 100 * \
    Balt_percentages["# households no computer"].astype(
        int) / Balt_percentages["Total households"].astype(
        int) 
Balt_percentages["Percent no computer"] = Balt_percentages["Percent no computer"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent white  Percent Asian  \
# 0     15898.0                 15325.0  ...           30.4            2.6
#
#    Percent Hispanic origin  Percent two or more races  \
# 0                      5.1                        2.5
#
#    Percent 12th grade, no diploma  Percent graduated high school  \
# 0                             2.1                           25.0
#
#    Percent earned Associate's degree  Percent earned Bachelor's degree  \
# 0                                4.8                              16.3
#
#    Percent computer, no internet subscription  Percent no computer
# 0                                        12.2                 16.0
#
# [1 rows x 87 columns]

# %%
Balt_percentages["Percent less than 18 yrs old"] = 100 * \
    Balt_percentages["Pop. <18 years"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent less than 18 yrs old"] = Balt_percentages["Percent less than 18 yrs old"].astype(float).round(1)

# %%
# working age is 18-64 yrs old
Balt_percentages["Percent working age"] = 100 * \
    Balt_percentages["Pop. working age"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent working age"] = Balt_percentages["Percent working age"].astype(float).round(1)

# %%
Balt_percentages["Percent 65 or older"] = 100 * \
    Balt_percentages["Pop. 65+ years"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent 65 or older"] = Balt_percentages["Percent 65 or older"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent two or more races  \
# 0     15898.0                 15325.0  ...                        2.5
#
#    Percent 12th grade, no diploma  Percent graduated high school  \
# 0                             2.1                           25.0
#
#    Percent earned Associate's degree  Percent earned Bachelor's degree  \
# 0                                4.8                              16.3
#
#    Percent computer, no internet subscription  Percent no computer  \
# 0                                        12.2                 16.0
#
#    Percent less than 18 yrs old  Percent working age  Percent 65 or older
# 0                          20.9                 66.0                 13.2
#
# [1 rows x 90 columns]

# %%
Balt_percentages["Percent Foreign-born"] = 100 * \
    Balt_percentages["# Foreign-born"].astype(
        int) / Balt_percentages["Population"].astype(
        int) 
Balt_percentages["Percent Foreign-born"] = Balt_percentages["Percent Foreign-born"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent 12th grade, no diploma  \
# 0     15898.0                 15325.0  ...                             2.1
#
#    Percent graduated high school  Percent earned Associate's degree  \
# 0                           25.0                                4.8
#
#    Percent earned Bachelor's degree  \
# 0                              16.3
#
#    Percent computer, no internet subscription  Percent no computer  \
# 0                                        12.2                 16.0
#
#    Percent less than 18 yrs old  Percent working age  Percent 65 or older  \
# 0                          20.9                 66.0                 13.2
#
#    Percent Foreign-born
# 0                   8.1
#
# [1 rows x 91 columns]

# %%
Balt_percentages["Construction"] = 100 * \
    Balt_percentages["Construction count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Construction"] = Balt_percentages["Construction"].astype(float).round(1)

# %%
Balt_percentages["Manufacturing"] = 100 * \
    Balt_percentages["Manufacturing count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Manufacturing"] = Balt_percentages["Manufacturing"].astype(float).round(1)

# %%
Balt_percentages["Retail Trade"] = 100 * \
    Balt_percentages["Retail_Trade count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Retail Trade"] = Balt_percentages["Retail Trade"].astype(float).round(1)

# %%
Balt_percentages["Transportation, warehousing, utilities"] = 100 * \
    Balt_percentages["Transportation_warehousing_utilities count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Transportation, warehousing, utilities"] = Balt_percentages["Transportation, warehousing, utilities"].astype(float).round(1)

# %%
Balt_percentages["Finance, insurance, real estate"] = 100 * \
    Balt_percentages["Finance_insurance_realestate count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Finance, insurance, real estate"] = Balt_percentages["Finance, insurance, real estate"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent no computer  \
# 0     15898.0                 15325.0  ...                 16.0
#
#    Percent less than 18 yrs old  Percent working age  Percent 65 or older  \
# 0                          20.9                 66.0                 13.2
#
#    Percent Foreign-born  Construction  Manufacturing  Retail Trade  \
# 0                   8.1           4.5            4.4           9.4
#
#    Transportation, warehousing, utilities  Finance, insurance, real estate
# 0                                     5.8                              5.6
#
# [1 rows x 96 columns]

# %%
Balt_percentages["Professional, scientific, mgmt, administrative"] = 100 * \
    Balt_percentages["Professional_scientific_mgmt_administrative count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Professional, scientific, mgmt, administrative"] = Balt_percentages["Professional, scientific, mgmt, administrative"].astype(float).round(1)

# %%
Balt_percentages["Educational services, health care, social assistance"] = 100 * \
    Balt_percentages["Educational_healthcare_social count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Educational services, health care, social assistance"] = Balt_percentages["Educational services, health care, social assistance"].astype(float).round(1)

# %%
Balt_percentages["Accommodations, food services, arts, entertainment"] = 100 * \
    Balt_percentages["Accommodations_foodservices_arts_entertainment count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Accommodations, food services, arts, entertainment"] = Balt_percentages["Accommodations, food services, arts, entertainment"].astype(float).round(1)

# %%
Balt_percentages["Public administration"] = 100 * \
    Balt_percentages["Public_administration count"].astype(
        int) / Balt_percentages["Civilian_employed_pop_16yrs_and_over"].astype(
        int) 
Balt_percentages["Public administration"] = Balt_percentages["Public administration"].astype(float).round(1)
Balt_percentages
# Out:
#                        Name  Household population  Total households  \
# 0  Baltimore city, Maryland              590812.0          238436.0
#
#    Median household income  Population  Median age  Pop. white  Pop. Black  \
# 0                  48840.0    614700.0        35.1    187152.0    383918.0
#
#    Pop. Asian  Pop. two or more races  ...  Percent Foreign-born  \
# 0     15898.0                 15325.0  ...                   8.1
#
#    Construction  Manufacturing  Retail Trade  \
# 0           4.5            4.4           9.4
#
#    Transportation, warehousing, utilities  Finance, insurance, real estate  \
# 0                                     5.8                              5.6
#
#    Professional, scientific, mgmt, administrative  \
# 0                                            12.5
#
#    Educational services, health care, social assistance  \
# 0                                                  31.7
#
#    Accommodations, food services, arts, entertainment  Public administration
# 0                                                 9.1                    8.1
#
# [1 rows x 100 columns]

# %%
# Replace column name "Name" so we can match it on "Corridor" column at a later step
Balt_percentages = Balt_percentages.rename(columns={"Name": "Corridor",
                                      "Percent white": "Percent White",
                                      "Percent 2 or more races": "Percent two or more races"
                                           })

# %%
# remove median household income and median age columns for now
# ADD THEM BACK LATER!!!!!!!!!!!!!!!!!!!!!!!!
Balt_percentages = Balt_percentages.drop(["Median household income", "Median age"], axis=1)

# %%
# Change order of columns in DataFrame by using double brackets. to match column order of ACS5YR-detailed-tables-2021.ipynb

Balt_percentages = Balt_percentages[["Corridor", "Population", "Total households", "Household population", 
                       "Pop. density per sq mile","Income_past_12mos_below_pov_level",             
                       "Persons_poverty_status_determined",
                       "Pop_16_yrs_and_over", "Pop_in_labor_force", "Pop_NOT_in_labor_force",
                       "Employed_civilians", "Unemployed_civilians", "Workers_16_yrs_and_over",
                       "Population_25_yrs_and_over", "# persons 12th grade, no diploma",
                       "# persons graduated high school", "# persons Associate's degree",
                       "# persons Bachelor's degree",             
                       "Pop. Asian", "Pop. Black", "Pop. Hispanic origin", "Pop. white",            
                       "Pop. two or more races", "# Foreign-born", "Total pop. in occupied housing units by tenure",
                       "Total occupied units", "Total owner-occupied units", "Total renter-occupied units",
                       "No_vehicle_available_owneroccupied_unit", "No_vehicle_available_renteroccupied_unit",
                       "# households with computer, no internet subscription", "# households no computer",
                       "Pop. <18 years", "Pop. working age", "Pop. 65+ years",
                       "Commute_to_work_public_transportation", "Civilian_employed_pop_16yrs_and_over", 
                       "Construction count", "Manufacturing count", "Retail_Trade count","Transportation_warehousing_utilities count",                
                       "Finance_insurance_realestate count", "Professional_scientific_mgmt_administrative count",               
                       "Educational_healthcare_social count", "Accommodations_foodservices_arts_entertainment count",
                       "Public_administration count", "Area_Acres", "Area_mi2",
                       "Home ownership rate", 
                       "Average hh size", "Number units with no vehicle available",
                       "Percent units with no vehicle available",
                       "Percent commute to work public transportation", "Percent Asian",
                       "Percent Black", "Percent Hispanic origin", "Percent White",
                       "Percent two or more races", "Percent 12th grade, no diploma",
                       "Percent graduated high school", "Percent earned Associate's degree",
                       "Percent earned Bachelor's degree",
                       "Percent computer, no internet subscription", "Percent no computer",
                       "Percent less than 18 yrs old", "Percent working age",
                       "Percent 65 or older", "Percent Foreign-born", "Construction","Manufacturing",
                       "Retail Trade",
                       "Transportation, warehousing, utilities",
                       "Finance, insurance, real estate",
                       "Professional, scientific, mgmt, administrative",
                       "Educational services, health care, social assistance",
                       "Accommodations, food services, arts, entertainment",
                       "Public administration"      
                        ]]

Balt_percentages.head()
# Out:
#                    Corridor  Population  Total households  \
# 0  Baltimore city, Maryland    614700.0          238436.0
#
#    Household population  Pop. density per sq mile  \
# 0              590812.0                    6661.2
#
#    Income_past_12mos_below_pov_level  Persons_poverty_status_determined  \
# 0                           128829.0                           591942.0
#
#    Pop_16_yrs_and_over  Pop_in_labor_force  Pop_NOT_in_labor_force  ...  \
# 0             498965.0            307536.0                191429.0  ...
#
#    Percent Foreign-born  Construction  Manufacturing  Retail Trade  \
# 0                   8.1           4.5            4.4           9.4
#
#    Transportation, warehousing, utilities  Finance, insurance, real estate  \
# 0                                     5.8                              5.6
#
#    Professional, scientific, mgmt, administrative  \
# 0                                            12.5
#
#    Educational services, health care, social assistance  \
# 0                                                  31.7
#
#    Accommodations, food services, arts, entertainment  Public administration
# 0                                                 9.1                    8.1
#
# [1 rows x 77 columns]

# %%
Balt_percentages['Corridor'] = Balt_percentages['Corridor'].str.replace("Baltimore city, Maryland", "Baltimore City")
Balt_percentages
# Out:
#          Corridor  Population  Total households  Household population  \
# 0  Baltimore City    614700.0          238436.0              590812.0
#
#    Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 0                    6661.2                           128829.0
#
#    Persons_poverty_status_determined  Pop_16_yrs_and_over  Pop_in_labor_force  \
# 0                           591942.0             498965.0            307536.0
#
#    Pop_NOT_in_labor_force  ...  Percent Foreign-born  Construction  \
# 0                191429.0  ...                   8.1           4.5
#
#    Manufacturing  Retail Trade  Transportation, warehousing, utilities  \
# 0            4.4           9.4                                     5.8
#
#    Finance, insurance, real estate  \
# 0                              5.6
#
#    Professional, scientific, mgmt, administrative  \
# 0                                            12.5
#
#    Educational services, health care, social assistance  \
# 0                                                  31.7
#
#    Accommodations, food services, arts, entertainment  Public administration
# 0                                                 9.1                    8.1
#
# [1 rows x 77 columns]

# %%
#Balt_percentages.columns

# %%
# Export file as an Excel file (will merge this file with the corridor info. in "ACS5YR-detailed-tables-2021.ipynb")
#Balt_percentages.to_excel("BaltCity_demographics_2021.xlsx")

# %%
# export as csv - will the import into the "ACS5YR-detailed-tables-2021" nb and merge with dataframe
# ignore "percentages" in name - file includes counts as well as percentages
Balt_percentages.to_csv("BaltCity_demographics_2012-2016.csv", index = False, header=True)

# %%
# If want to transpose....

# %%
#Greektown_percentages = Greektown_percentages.T
#Greektown_percentages

# %%
#Greektown_percentages.reset_index().rename(columns={'index':'Category'})
#Greektown_percentages

# %%
# make the first row the header
#Greektown_percentages = Greektown_percentages.rename(columns=Greektown_percentages.iloc[0]).drop(Greektown_percentages.index[0])
#Greektown_percentages = Greektown_percentages.reset_index().rename(columns={'index': 'Metric'})
#Greektown_percentages.drop(index=Greektown_percentages.index[0], axis=0,inplace=True)
#Greektown_percentages
