# %%
# Correlations Charts - 2021 data for all corridors

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import style
# %matplotlib inline

# %%
pd.set_option('max_colwidth', 250)

# %%
pd.set_option('display.max_rows', 200)

# %%
data_2021 = "./temp/corridors_vacants_2021.csv"
df_2021 = pd.read_csv(data_2021)
df_2021
# Out:
#                Corridor  Population  Total households  Household population  \
# 0             Belair Rd       35458             12487                 33302
# 1              Brooklyn       13989              5613                 13954
# 2         E Monument St       48947             19537                 48257
# 3             Greektown       10968              3832                 10821
# 4   Hamilton Lauraville       36997             13384                 35548
# 5               Hampden       27062              8497                 19748
# 6          Highlandtown       26400             11368                 25721
# 7             Irvington       11585              4633                 11291
# 8             North Ave       15602              5403                 15490
# 9          Park Heights       14908              6156                 14475
# 10             Penn Ave       59969             24412                 57069
# 11              Pigtown       24194              8919                 23420
# 12              Pimlico       32244             12215                 31707
# 13              Waverly       39117             16374                 35868
#
#     Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 0                     8265.4                               7420
# 1                     6284.4                               3203
# 2                    10155.1                              12082
# 3                     4134.0                               1118
# 4                     7548.4                               5274
# 5                     9370.7                               2467
# 6                     6478.9                               4471
# 7                     5826.8                               1839
# 8                    10767.0                               4929
# 9                    12257.5                               3772
# 10                    8589.6                              14610
# 11                    6669.8                               5599
# 12                    3231.3                               6678
# 13                   11372.4                               7085
#
#     Persons_poverty_status_determined  Pop_16_yrs_and_over  \
# 0                               33273                27588
# 1                               13938                11356
# 2                               48357                38934
# 3                               10631                 8559
# 4                               35323                28914
# 5                               19829                23804
# 6                               25936                21875
# 7                               11334                 9565
# 8                               15452                12543
# 9                               14737                12587
# 10                              57178                48426
# 11                              23396                19699
# 12                              31709                26135
# 13                              36049                33936
#
#     Pop_in_labor_force  Pop_NOT_in_labor_force  ...  \
# 0                16396                   11192  ...
# 1                 7586                    3770  ...
# 2                24444                   14490  ...
# 3                 5908                    2651  ...
# 4                18848                   10066  ...
# 5                12242                   11562  ...
# 6                14404                    7471  ...
# 7                 6193                    3372  ...
# 8                 6784                    5759  ...
# 9                 6940                    5647  ...
# 10               29096                   19330  ...
# 11               12388                    7311  ...
# 12               14632                   11503  ...
# 13               22639                   11297  ...
#
#     Finance, insurance, real estate  \
# 0                               5.8
# 1                               4.9
# 2                               5.7
# 3                               7.9
# 4                               5.9
# 5                               6.9
# 6                               8.7
# 7                               3.3
# 8                               5.0
# 9                               5.1
# 10                              4.7
# 11                              5.3
# 12                              5.4
# 13                              5.1
#
#     Professional, scientific, mgmt, administrative  \
# 0                                             12.0
# 1                                             13.8
# 2                                             13.0
# 3                                             15.5
# 4                                             11.6
# 5                                             13.1
# 6                                             13.3
# 7                                             11.2
# 8                                             10.3
# 9                                             13.9
# 10                                            12.2
# 11                                             9.5
# 12                                             8.5
# 13                                            13.3
#
#     Educational services, health care, social assistance  \
# 0                                                   30.7
# 1                                                   26.2
# 2                                                   37.0
# 3                                                   20.3
# 4                                                   33.1
# 5                                                   35.3
# 6                                                   29.9
# 7                                                   29.4
# 8                                                   30.7
# 9                                                   37.6
# 10                                                  31.2
# 11                                                  30.7
# 12                                                  31.0
# 13                                                  39.2
#
#     Accommodations, food services, arts, entertainment  Public administration  \
# 0                                                  8.0                   11.3
# 1                                                  8.1                    8.1
# 2                                                  8.7                    7.1
# 3                                                 12.8                    4.1
# 4                                                  6.7                    8.1
# 5                                                 10.3                    5.6
# 6                                                  7.1                    7.9
# 7                                                  7.8                    6.1
# 8                                                  9.9                    9.1
# 9                                                  7.3                    6.9
# 10                                                10.6                    9.3
# 11                                                10.9                    8.1
# 12                                                 8.9                    9.6
# 13                                                 7.1                    6.1
#
#     Business vacancies <24 months  Business vacancies >24 months  \
# 0                              18                             43
# 1                              16                             94
# 2                              35                            141
# 3                               9                             27
# 4                              25                            107
# 5                              38                             80
# 6                              39                             91
# 7                               6                             44
# 8                               7                            109
# 9                               7                             41
# 10                            117                            353
# 11                             31                            193
# 12                             10                            151
# 13                             21                            134
#
#     Business no-stat <24 months  Business no-stat >24 months  Year
# 0                           206                          207  2021
# 1                           323                          300  2021
# 2                           359                          379  2021
# 3                           192                          201  2021
# 4                           383                          369  2021
# 5                           181                          163  2021
# 6                           318                          332  2021
# 7                           111                          112  2021
# 8                           174                          173  2021
# 9                           172                          170  2021
# 10                         1140                         1056  2021
# 11                          274                          267  2021
# 12                          235                          257  2021
# 13                          561                          558  2021
#
# [14 rows x 84 columns]

# %%
df_2021.columns
# Out:
# Index(['Corridor', 'Population', 'Total households', 'Household population',
#        'Pop. density per sq mile', 'Income_past_12mos_below_pov_level',
#        'Persons_poverty_status_determined', 'Pop_16_yrs_and_over',
#        'Pop_in_labor_force', 'Pop_NOT_in_labor_force', 'Employed_civilians',
#        'Unemployed_civilians', 'Workers_16_yrs_and_over',
#        'Population_25_yrs_and_over', '# persons 12th grade, no diploma',
#        '# persons graduated high school', '# persons Associate's degree',
#        '# persons Bachelor's degree', 'Pop. Asian', 'Pop. Black',
#        'Pop. Hispanic origin', 'Pop. white', 'Pop. two or more races',
#        '# Foreign-born', 'Total pop. in occupied housing units by tenure',
#        'Total occupied units', 'Total owner-occupied units',
#        'Total renter-occupied units',
#        'No_vehicle_available_owneroccupied_unit',
#        'No_vehicle_available_renteroccupied_unit',
#        '# households with computer, no internet subscription',
#        '# households no computer', 'Pop. <18 years', 'Pop. working age',
#        'Pop. 65+ years', 'Commute_to_work_public_transportation',
#        'Civilian_employed_pop_16yrs_and_over', 'Construction count',
#        'Manufacturing count', 'Retail_Trade count',
#        'Transportation_warehousing_utilities count',
#        'Finance_insurance_realestate count',
#        'Professional_scientific_mgmt_administrative count',
#        'Educational_healthcare_social count',
#        'Accommodations_foodservices_arts_entertainment count',
#        'Public_administration count', 'Area_Acres', 'Area_mi2',
#        'Home ownership rate', 'Poverty rate', 'Unemployment rate',
#        'Average hh size', 'Number units with no vehicle available',
#        'Percent units with no vehicle available',
#        'Percent commute to work public transportation', 'Percent Asian',
#        'Percent Black', 'Percent Hispanic origin', 'Percent White',
#        'Percent two or more races', 'Percent 12th grade, no diploma',
#        'Percent graduated high school', 'Percent earned Associate's degree',
#        'Percent earned Bachelor's degree',
#        'Percent computer, no internet subscription', 'Percent no computer',
#        'Percent less than 18 yrs old', 'Percent working age',
#        'Percent 65 or older', 'Percent Foreign-born', 'Construction',
#        'Manufacturing', 'Retail Trade',
#        'Transportation, warehousing, utilities',
#        'Finance, insurance, real estate',
#        'Professional, scientific, mgmt, administrative',
#        'Educational services, health care, social assistance',
#        'Accommodations, food services, arts, entertainment',
#        'Public administration', 'Business vacancies <24 months',
#        'Business vacancies >24 months', 'Business no-stat <24 months',
#        'Business no-stat >24 months', 'Year'],
#       dtype='object')

# %%
not_labor_force = df_2021.sort_values(by=["Pop_NOT_in_labor_force"], ascending=False)
not_labor_force = not_labor_force[["Corridor", "Pop_NOT_in_labor_force"]]
not_labor_force
# Out:
#                Corridor  Pop_NOT_in_labor_force
# 10             Penn Ave                   19330
# 2         E Monument St                   14490
# 5               Hampden                   11562
# 12              Pimlico                   11503
# 13              Waverly                   11297
# 0             Belair Rd                   11192
# 4   Hamilton Lauraville                   10066
# 6          Highlandtown                    7471
# 11              Pigtown                    7311
# 8             North Ave                    5759
# 9          Park Heights                    5647
# 1              Brooklyn                    3770
# 7             Irvington                    3372
# 3             Greektown                    2651

# %%
# compare number vacancies with demographics, use smaller dfs for simplicity
vacancies_df = df_2021[["Business vacancies >24 months", "Pop. density per sq mile", "Percent earned Bachelor's degree", "Home ownership rate",
                       "Poverty rate", "Unemployment rate", "Percent no computer", "Percent Black", "Percent working age"]]

# %%
# Pearson's correlation
#  r < 0.3 none or very weak correlation
#  0.3 < or = r < 0.5  weak correlation
#  0.5 < or = r < 0.7  moderate correlation
#  r > or = 0.7 strong correlation

# %%
# CORRELATIONS
# See https://www.youtube.com/watch?v=0U9cs2V-Mqc; 
# https://heartbeat.comet.ml/seaborn-heatmaps-13-ways-to-customize-correlation-matrix-visualizations-f1c49c816f07
# Plot - Pearson correlation

sns.heatmap(vacancies_df.corr(),annot = True, annot_kws={"fontsize":6},vmin=-1, vmax=1, center=0, cmap='coolwarm')
plt.title('Correlations - Census Data')
plt.show()

# %%
# Pearson's correlation
#  r < 0.3 none or very weak correlation
#  0.3 < or = r < 0.5  weak correlation
#  0.5 < or = r < 0.7  moderate correlation
#  r > or = 0.7 strong correlation

# only need the bottom half of the matrix as the top right "triangle" is redundant
corr = vacancies_df.corr()

matrix = np.triu(corr)

# make heatmap using Seaborn "coolwarm" colormap
sns.heatmap(corr,annot = True, mask=matrix, annot_kws={"fontsize":6},vmin=-1, vmax=1, center=0, cmap='coolwarm_r')
plt.title('Correlations - Census Data')
plt.show()

# Save graph as a png file
#plt.savefig("correlation.png")

# %%
# only need the bottom half of the matrix as the top right "triangle" is redundant

corr = vacancies_df.corr()

matrix = np.triu(corr)

# # using "rocket" color map: use _r to reverse, ex. "rocket_r"
sns.heatmap(corr,annot = True, mask=matrix, annot_kws={"fontsize":6},vmin=-1, vmax=1, center=0, cmap='rocket')
plt.title('Correlations - Census Data')
plt.show()

# Save graph as a png file
#plt.savefig("correlation.png")

# %%
# create scatterplot
corr = df_2021['Corridor']
pop = df_2021['Population']
povcount = df_2021['Poverty rate']
Black = df_2021['Percent Black']

plt.scatter(povcount, Black, edgecolors='r')

#x-axis labels 
plt.xlabel('Poverty rate') 

#y-axis labels 
plt.ylabel('Percent Black') 

#plot title 
plt.title('Black Population vs. Poverty rate - 2021') 

plt.show()

# %%
# Show corridor with largest # of working age population
df_2021[ df_2021['Pop. working age'] == df_2021['Pop. working age'].max()]
# Out:
#     Corridor  Population  Total households  Household population  \
# 10  Penn Ave       59969             24412                 57069
#
#     Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 10                    8589.6                              14610
#
#     Persons_poverty_status_determined  Pop_16_yrs_and_over  \
# 10                              57178                48426
#
#     Pop_in_labor_force  Pop_NOT_in_labor_force  ...  \
# 10               29096                   19330  ...
#
#     Finance, insurance, real estate  \
# 10                              4.7
#
#     Professional, scientific, mgmt, administrative  \
# 10                                            12.2
#
#     Educational services, health care, social assistance  \
# 10                                                  31.2
#
#     Accommodations, food services, arts, entertainment  Public administration  \
# 10                                                10.6                    9.3
#
#     Business vacancies <24 months  Business vacancies >24 months  \
# 10                            117                            353
#
#     Business no-stat <24 months  Business no-stat >24 months  Year
# 10                         1140                         1056  2021
#
# [1 rows x 84 columns]

# %%
# Show corridor with lowest # of working age population
df_2021[ df_2021['Pop. working age'] == df_2021['Pop. working age'].min()]
# Out:
#     Corridor  Population  Total households  Household population  \
# 3  Greektown       10968              3832                 10821
#
#    Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 3                    4134.0                               1118
#
#    Persons_poverty_status_determined  Pop_16_yrs_and_over  Pop_in_labor_force  \
# 3                              10631                 8559                5908
#
#    Pop_NOT_in_labor_force  ...  Finance, insurance, real estate  \
# 3                    2651  ...                              7.9
#
#    Professional, scientific, mgmt, administrative  \
# 3                                            15.5
#
#    Educational services, health care, social assistance  \
# 3                                                  20.3
#
#    Accommodations, food services, arts, entertainment  Public administration  \
# 3                                                12.8                    4.1
#
#    Business vacancies <24 months  Business vacancies >24 months  \
# 3                              9                             27
#
#    Business no-stat <24 months  Business no-stat >24 months  Year
# 3                          192                          201  2021
#
# [1 rows x 84 columns]

# %%
# Using .to_numeric can make it easier to do calculations, if you need to change a data point from an "object," for example
#pd.to_numeric(df_2016['Population'])

# %%
#df_2021['Year']= "2021"
#df_2021.info()

# %%
# Show corridor with greatest population
df_2021[ df_2021['Population'] == df_2021['Population'].max()]
# Out:
#     Corridor  Population  Total households  Household population  \
# 10  Penn Ave       59969             24412                 57069
#
#     Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 10                    8589.6                              14610
#
#     Persons_poverty_status_determined  Pop_16_yrs_and_over  \
# 10                              57178                48426
#
#     Pop_in_labor_force  Pop_NOT_in_labor_force  ...  \
# 10               29096                   19330  ...
#
#     Finance, insurance, real estate  \
# 10                              4.7
#
#     Professional, scientific, mgmt, administrative  \
# 10                                            12.2
#
#     Educational services, health care, social assistance  \
# 10                                                  31.2
#
#     Accommodations, food services, arts, entertainment  Public administration  \
# 10                                                10.6                    9.3
#
#     Business vacancies <24 months  Business vacancies >24 months  \
# 10                            117                            353
#
#     Business no-stat <24 months  Business no-stat >24 months  Year
# 10                         1140                         1056  2021
#
# [1 rows x 84 columns]

# %%
# Show corridor with lowest population
df_2021[ df_2021['Population'] == df_2021['Population'].min()]
# Out:
#     Corridor  Population  Total households  Household population  \
# 3  Greektown       10968              3832                 10821
#
#    Pop. density per sq mile  Income_past_12mos_below_pov_level  \
# 3                    4134.0                               1118
#
#    Persons_poverty_status_determined  Pop_16_yrs_and_over  Pop_in_labor_force  \
# 3                              10631                 8559                5908
#
#    Pop_NOT_in_labor_force  ...  Finance, insurance, real estate  \
# 3                    2651  ...                              7.9
#
#    Professional, scientific, mgmt, administrative  \
# 3                                            15.5
#
#    Educational services, health care, social assistance  \
# 3                                                  20.3
#
#    Accommodations, food services, arts, entertainment  Public administration  \
# 3                                                12.8                    4.1
#
#    Business vacancies <24 months  Business vacancies >24 months  \
# 3                              9                             27
#
#    Business no-stat <24 months  Business no-stat >24 months  Year
# 3                          192                          201  2021
#
# [1 rows x 84 columns]

# %%
df_2021.dtypes
# Out:
# Corridor                                                 object
# Population                                                int64
# Total households                                          int64
# Household population                                      int64
# Pop. density per sq mile                                float64
# Income_past_12mos_below_pov_level                         int64
# Persons_poverty_status_determined                         int64
# Pop_16_yrs_and_over                                       int64
# Pop_in_labor_force                                        int64
# Pop_NOT_in_labor_force                                    int64
# Employed_civilians                                        int64
# Unemployed_civilians                                      int64
# Workers_16_yrs_and_over                                   int64
# Population_25_yrs_and_over                                int64
# # persons 12th grade, no diploma                          int64
# # persons graduated high school                           int64
# # persons Associate's degree                              int64
# # persons Bachelor's degree                               int64
# Pop. Asian                                                int64
# Pop. Black                                                int64
# Pop. Hispanic origin                                      int64
# Pop. white                                                int64
# Pop. two or more races                                    int64
# # Foreign-born                                            int64
# Total pop. in occupied housing units by tenure            int64
# Total occupied units                                      int64
# Total owner-occupied units                                int64
# Total renter-occupied units                               int64
# No_vehicle_available_owneroccupied_unit                   int64
# No_vehicle_available_renteroccupied_unit                  int64
# # households with computer, no internet subscription      int64
# # households no computer                                  int64
# Pop. <18 years                                            int64
# Pop. working age                                          int64
# Pop. 65+ years                                            int64
# Commute_to_work_public_transportation                     int64
# Civilian_employed_pop_16yrs_and_over                      int64
# Construction count                                        int64
# Manufacturing count                                       int64
# Retail_Trade count                                        int64
# Transportation_warehousing_utilities count                int64
# Finance_insurance_realestate count                        int64
# Professional_scientific_mgmt_administrative count         int64
# Educational_healthcare_social count                       int64
# Accommodations_foodservices_arts_entertainment count      int64
# Public_administration count                               int64
# Area_Acres                                              float64
# Area_mi2                                                float64
# Home ownership rate                                     float64
# Poverty rate                                            float64
# Unemployment rate                                       float64
# Average hh size                                         float64
# Number units with no vehicle available                    int64
# Percent units with no vehicle available                 float64
# Percent commute to work public transportation           float64
# Percent Asian                                           float64
# Percent Black                                           float64
# Percent Hispanic origin                                 float64
# Percent White                                           float64
# Percent two or more races                               float64
# Percent 12th grade, no diploma                          float64
# Percent graduated high school                           float64
# Percent earned Associate's degree                       float64
# Percent earned Bachelor's degree                        float64
# Percent computer, no internet subscription              float64
# Percent no computer                                     float64
# Percent less than 18 yrs old                            float64
# Percent working age                                     float64
# Percent 65 or older                                     float64
# Percent Foreign-born                                    float64
# Construction                                            float64
# Manufacturing                                           float64
# Retail Trade                                            float64
# Transportation, warehousing, utilities                  float64
# Finance, insurance, real estate                         float64
# Professional, scientific, mgmt, administrative          float64
# Educational services, health care, social assistance    float64
# Accommodations, food services, arts, entertainment      float64
# Public administration                                   float64
# Business vacancies <24 months                             int64
# Business vacancies >24 months                             int64
# Business no-stat <24 months                               int64
# Business no-stat >24 months                               int64
# Year                                                      int64
# dtype: object

# %%
# See https://www.youtube.com/watch?v=crQkHHhY7aY
# corr = df.corr()
sns.clustermap(df_2021)
plt.title('Clustermap of Census Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6880\3968991702.py in <module>
#       1 # See https://www.youtube.com/watch?v=crQkHHhY7aY
#       2 # corr = df.corr()
# ----> 3 sns.clustermap(df_2021)
#       4 plt.title('Clustermap of Census Data')
#       5 plt.show()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1260                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1261                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1262                         tree_kws=tree_kws, **kwargs)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1129         self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1130                               row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1131                               tree_kws=tree_kws)
#    1132         try:
#    1133             xind = self.dendrogram_col.reordered_ind
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#     975                 self.data2d, metric=metric, method=method, label=False, axis=0,
#     976                 ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
# --> 977                 tree_kws=tree_kws
#     978             )
#     979         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     687     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     688                                  metric=metric, method=method,
# --> 689                                  label=label, rotate=rotate)
#     690     if ax is None:
#     691         ax = plt.gca()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in __init__(self, data, linkage, metric, method, axis, label, rotate)
#     493
#     494         if linkage is None:
# --> 495             self.linkage = self.calculated_linkage
#     496         else:
#     497             self.linkage = linkage
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in calculated_linkage(self)
#     560                 warnings.warn(msg)
#     561
# --> 562         return self._calculate_linkage_scipy()
#     563
#     564     def calculate_dendrogram(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\matrix.py in _calculate_linkage_scipy(self)
#     529     def _calculate_linkage_scipy(self):
#     530         linkage = hierarchy.linkage(self.array, method=self.method,
# --> 531                                     metric=self.metric)
#     532         return linkage
#     533
#
# ~\anaconda3\envs\PythonData\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1044         raise ValueError("Invalid method: {0}".format(method))
#    1045
# -> 1046     y = _convert_to_double(np.asarray(y, order='c'))
#    1047
#    1048     if y.ndim == 1:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\scipy\cluster\hierarchy.py in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
#    1574         X = X.copy()
#
# ValueError: could not convert string to float: 'Belair Rd'

# %%
# Plot after scaling the data
sns.clustermap(df_21, standard_scale=1)
plt.title('Clustermap of Census Data')
plt.show()

# Save graph as a png file
#plt.savefig("clustermap.png")

# %%
# HEATMAP
#Plot 
sns.heatmap(df_2021)
plt.title('Heatmap of Census Data')
plt.show()

# Save graph as a png file
#plt.savefig("heatmap.png")

# %%
#df_2020_tracts.corr()
